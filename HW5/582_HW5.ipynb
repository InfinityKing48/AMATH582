# %%
import numpy as np
import matplotlib.pyplot as plt
import cvxpy as cvx
import skimage as ski

import skimage.io
import skimage.transform

import scipy.fftpack as spfft

# %% [markdown]
# # Image Compression

# %%
img_path = 'SonOfMan.png'

img_og = ski.io.imread(img_path)

img_og = ski.color.rgb2gray(img_og)

fig, ax = plt.subplots(1, 2, figsize=(20,10))
ax[0].imshow(img_og, cmap = 'gray')
ax[0].set_title("Original image")

print("Original size: ", img_og.shape)

img = ski.transform.rescale(img_og, 0.18, anti_aliasing=False)

print("Rescaled size: ", img.shape)

ax[1].imshow(img, cmap='gray')
ax[1].set_title("Rescaled image")
# Out:
# Original size:  (292, 228)
# Rescaled size:  (53, 41)
# C:\Users\King48\AppData\Local\Temp/ipykernel_38348/366801795.py:5: FutureWarning: Non RGB image conversion is now deprecated. For RGBA images, please use rgb2gray(rgba2rgb(rgb)) instead. In version 0.19, a ValueError will be raised if input image last dimension length is not 3.
#   img_og = ski.color.rgb2gray(img_og)
# Text(0.5, 1.0, 'Rescaled image')

# %%
def construct_DCT_Mat(Nx, Ny):

  Dx = spfft.dct(np.eye(Nx), axis =0, norm='ortho')

  Dy = spfft.dct(np.eye(Ny), axis = 0, norm='ortho')

  D = np.kron(Dy, Dx)

  return D

def construct_iDCT_Mat(Nx, Ny):

  Dx = spfft.idct(np.eye(Nx), axis =0, norm='ortho')

  Dy = spfft.idct(np.eye(Ny), axis = 0, norm = 'ortho')

  D = np.kron(Dy, Dx)

  return D

# %%
Nx = img.shape[1]
Ny = img.shape[0]

DCT_mat = construct_DCT_Mat(Nx, Ny)
iDCT_mat = construct_iDCT_Mat(Nx, Ny)

vec_F = img.flatten()

# %%
DCT_img = np.dot(DCT_mat, vec_F)

plt.figure(figsize=(10, 10))
plt.plot(np.abs(DCT_img))
plt.xlabel('Index', fontsize=16)
plt.ylabel('Coefficients', fontsize=16)
plt.show()

# %%
magnitude_5 = np.percentile(np.abs(DCT_img), 100 - 5)
magnitude_10 = np.percentile(np.abs(DCT_img), 100 - 10)
magnitude_20 = np.percentile(np.abs(DCT_img), 100 - 20)
magnitude_40 = np.percentile(np.abs(DCT_img), 100 - 40)

thresholded_DCT_5 = np.where(np.abs(DCT_img) >= magnitude_5, DCT_img, 0)
thresholded_DCT_10 = np.where(np.abs(DCT_img) >= magnitude_10, DCT_img, 0)
thresholded_DCT_20 = np.where(np.abs(DCT_img) >= magnitude_20, DCT_img, 0)
thresholded_DCT_40 = np.where(np.abs(DCT_img) >= magnitude_40, DCT_img, 0)

Re_img_5 = np.dot(iDCT_mat, thresholded_DCT_5)
Re_img_10 = np.dot(iDCT_mat, thresholded_DCT_10)
Re_img_20 = np.dot(iDCT_mat, thresholded_DCT_20)
Re_img_40 = np.dot(iDCT_mat, thresholded_DCT_40)

# %%
Re = [Re_img_5, Re_img_10, Re_img_20, Re_img_40]
Titles = ['5%', '10%', '20%', '40%']

fig, ax = plt.subplots(2, 2, figsize=(20,20))
for i in range(2):
    for j in range(2):
        ax[i][j].imshow(Re[i*2+j].reshape(53, 41), cmap='gray')
        ax[i][j].axis('off')
        ax[i][j].set_title('Keep the Top ' + Titles[i*2+j] + ' of DCT Coef' )
plt.show()

# %% [markdown]
# # Compressed Image Recovery

# %%
def construct_Measurement_Mat(M, N):

    i_mat = np.identity(N)
    sample_rows = np.random.permutation(N)
    B = i_mat[sample_rows[:M], :]

    return B

# %%
N = len(vec_F)
M = round(0.2 * N)
Bs = []

fig, ax = plt.subplots(1, 3, figsize=(30,10))
for i in range(3):
    B = construct_Measurement_Mat(M, N)
    ax[i].imshow(np.reshape(np.sum(B, axis = 0), (Ny, Nx)), cmap='gray')
    ax[i].axis('off')
    Bs.append(B)

# %%
fig, ax = plt.subplots(1, 3, figsize=(30,10))
for i in range(3):
    B = Bs[i]
    y = np.dot(B, vec_F)
    A = np.dot(B, iDCT_mat)
    x = cvx.Variable(N)
    objective = cvx.Minimize(cvx.norm(x, 1))
    constraint = [A @ x == y]
    prob = cvx.Problem(objective, constraint)
    prob.solve(verbose=True, solver='CVXOPT', max_iter=1000, reltol=1e-2, featol=1e-2)
    re_img = np.dot(iDCT_mat, x.value).reshape(Ny, Nx)
    ax[i].imshow(re_img, cmap='gray')
    ax[i].axis('off')
# Out:
# ===============================================================================
#                                      CVXPY
#                                      v1.2.0
# ===============================================================================
# (CVXPY) Mar 15 12:15:11 AM: Your problem has 2173 variables, 1 constraints, and 0 parameters.
# (CVXPY) Mar 15 12:15:11 AM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) Mar 15 12:15:11 AM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) Mar 15 12:15:11 AM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) Mar 15 12:15:11 AM: Compiling problem (target solver=CVXOPT).
# (CVXPY) Mar 15 12:15:11 AM: Reduction chain: Dcp2Cone -> CvxAttr2Constr -> ConeMatrixStuffing -> CVXOPT
# (CVXPY) Mar 15 12:15:11 AM: Applying reduction Dcp2Cone
# (CVXPY) Mar 15 12:15:11 AM: Applying reduction CvxAttr2Constr
# (CVXPY) Mar 15 12:15:11 AM: Applying reduction ConeMatrixStuffing
# (CVXPY) Mar 15 12:15:11 AM: Applying reduction CVXOPT
# (CVXPY) Mar 15 12:15:11 AM: Finished problem compilation (took 5.071e-01 seconds).
# -------------------------------------------------------------------------------
#                                 Numerical solver
# -------------------------------------------------------------------------------
# (CVXPY) Mar 15 12:15:11 AM: Invoking solver CVXOPT  to obtain a solution.
#      pcost       dcost       gap    pres   dres   k/t
#  0: -1.2972e-14 -3.1658e-15  1e+04  4e+02  4e-16  1e+00
#  1:  3.2160e+01  3.2294e+01  6e+03  2e+02  2e-16  6e-01
#  2:  4.6370e+01  4.6706e+01  2e+03  6e+01  4e-16  5e-01
#  3:  7.0648e+01  7.0791e+01  9e+02  3e+01  2e-16  2e-01
#  4:  9.4186e+01  9.4251e+01  4e+02  1e+01  3e-16  9e-02
#  5:  1.1117e+02  1.1120e+02  2e+02  6e+00  5e-16  4e-02
#  6:  1.2142e+02  1.2143e+02  8e+01  2e+00  5e-16  2e-02
#  7:  1.2618e+02  1.2618e+02  3e+01  1e+00  5e-16  8e-03
#  8:  1.2773e+02  1.2774e+02  2e+01  5e-01  6e-16  4e-03
#  9:  1.2867e+02  1.2867e+02  8e+00  2e-01  6e-16  2e-03
# 10:  1.2917e+02  1.2917e+02  3e+00  8e-02  6e-16  6e-04
# 11:  1.2931e+02  1.2931e+02  1e+00  4e-02  6e-16  3e-04
# 12:  1.2938e+02  1.2938e+02  6e-01  2e-02  6e-16  1e-04
# 13:  1.2942e+02  1.2942e+02  3e-01  8e-03  7e-16  6e-05
# 14:  1.2943e+02  1.2943e+02  1e-01  3e-03  6e-16  2e-05
# 15:  1.2944e+02  1.2944e+02  3e-02  9e-04  6e-16  7e-06
# 16:  1.2944e+02  1.2944e+02  5e-03  2e-04  6e-16  1e-06
# 17:  1.2944e+02  1.2944e+02  1e-03  4e-05  7e-16  3e-07
# 18:  1.2944e+02  1.2944e+02  2e-05  7e-07  7e-16  5e-09
# 19:  1.2944e+02  1.2944e+02  2e-07  7e-09  5e-14  5e-11
# Optimal solution found.
# -------------------------------------------------------------------------------
#                                     Summary
# -------------------------------------------------------------------------------
# (CVXPY) Mar 15 12:16:08 AM: Problem status: optimal
# (CVXPY) Mar 15 12:16:08 AM: Optimal value: 1.294e+02
# (CVXPY) Mar 15 12:16:08 AM: Compilation took 5.071e-01 seconds
# (CVXPY) Mar 15 12:16:08 AM: Solver (including time spent in interface) took 5.693e+01 seconds
# ===============================================================================
#                                      CVXPY
#                                      v1.2.0
# ===============================================================================
# (CVXPY) Mar 15 12
# 11:  1.2809e+02  1.2809e+02  9e-01  3e-02  6e-16  2e-04
# 12:  1.2815e+02  1.2815e+02  3e-01  1e-02  6e-16  8e-05
# 13:  1.2817e+02  1.2817e+02  1e-01  4e-03  6e-16  3e-05
# 14:  1.2818e+02  1.2818e+02  5e-02  1e-03  6e-16  1e-05
# 15:  1.2819e+02  1.2819e+02  1e-02  4e-04  7e-16  3e-06
# 16:  1.2819e+02  1.2819e+02  4e-03  1e-04  6e-16  9e-07
# 17:  1.2819e+02  1.2819e+02  9e-04  3e-05  6e-16  2e-07
# 18:  1.2819e+02  1.2819e+02  1e-04  4e-06  7e-16  3e-08
# 19:  1.2819e+02  1.2819e+02  3e-05  9e-07  3e-14  7e-09
# 20:  1.2819e+02  1.2819e+02  3e-07  1e-08  3e-14  8e-11
# Optimal solution found.
# -------------------------------------------------------------------------------
#                                     Summary
# -------------------------------------------------------------------------------
# (CVXPY) Mar 15 12:17:58 AM: Problem status: optimal
# (CVXPY) Mar 15 12:17:58 AM: Optimal value: 1.282e+02
# (CVXPY) Mar 15 12:17:58 AM: Compilation took 3.933e-01 seconds
# (CVXPY) Mar 15 12:17:58 AM: Solver (including time spent in interface) took 5.803e+01 seconds

# %%
M = round(0.4 * N)
Bs = []

fig, ax = plt.subplots(1, 3, figsize=(30,10))
for i in range(3):
    B = construct_Measurement_Mat(M, N)
    ax[i].imshow(np.reshape(np.sum(B, axis = 0), (Ny, Nx)), cmap='gray')
    ax[i].axis('off')
    Bs.append(B)

# %%
fig, ax = plt.subplots(1, 3, figsize=(30,10))
for i in range(3):
    B = Bs[i]
    y = np.dot(B, vec_F)
    A = np.dot(B, iDCT_mat)
    x = cvx.Variable(N)
    objective = cvx.Minimize(cvx.norm(x, 1))
    constraint = [A @ x == y]
    prob = cvx.Problem(objective, constraint)
    prob.solve(verbose=True, solver='CVXOPT', max_iter=1000, reltol=1e-2, featol=1e-2)
    re_img = np.dot(iDCT_mat, x.value).reshape(Ny, Nx)
    ax[i].imshow(re_img, cmap='gray')
    ax[i].axis('off')
# Out:
# ===============================================================================
#                                      CVXPY
#                                      v1.2.0
# ===============================================================================
# (CVXPY) Mar 15 12:19:41 AM: Your problem has 2173 variables, 1 constraints, and 0 parameters.
# (CVXPY) Mar 15 12:19:41 AM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) Mar 15 12:19:41 AM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) Mar 15 12:19:41 AM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) Mar 15 12:19:41 AM: Compiling problem (target solver=CVXOPT).
# (CVXPY) Mar 15 12:19:41 AM: Reduction chain: Dcp2Cone -> CvxAttr2Constr -> ConeMatrixStuffing -> CVXOPT
# (CVXPY) Mar 15 12:19:41 AM: Applying reduction Dcp2Cone
# (CVXPY) Mar 15 12:19:41 AM: Applying reduction CvxAttr2Constr
# (CVXPY) Mar 15 12:19:41 AM: Applying reduction ConeMatrixStuffing
# (CVXPY) Mar 15 12:19:42 AM: Applying reduction CVXOPT
# (CVXPY) Mar 15 12:19:42 AM: Finished problem compilation (took 9.233e-01 seconds).
# -------------------------------------------------------------------------------
#                                 Numerical solver
# -------------------------------------------------------------------------------
# (CVXPY) Mar 15 12:19:42 AM: Invoking solver CVXOPT  to obtain a solution.
#      pcost       dcost       gap    pres   dres   k/t
#  0: -8.4984e-14  1.0200e-14  3e+04  8e+02  5e-16  1e+00
#  1:  3.2094e+01  3.2442e+01  1e+04  3e+02  3e-16  8e-01
#  2:  5.0084e+01  5.0273e+01  2e+03  5e+01  3e-16  3e-01
#  3:  9.3105e+01  9.3193e+01  7e+02  2e+01  4e-16  1e-01
#  4:  1.3223e+02  1.3226e+02  2e+02  7e+00  6e-16  4e-02
#  5:  1.5967e+02  1.5968e+02  8e+01  2e+00  8e-16  1e-02
#  6:  1.6963e+02  1.6963e+02  3e+01  1e+00  8e-16  6e-03
#  7:  1.7281e+02  1.7281e+02  2e+01  5e-01  8e-16  3e-03
#  8:  1.7454e+02  1.7454e+02  6e+00  2e-01  9e-16  1e-03
#  9:  1.7528e+02  1.7528e+02  2e+00  8e-02  9e-16  5e-04
# 10:  1.7556e+02  1.7556e+02  1e+00  3e-02  9e-16  2e-04
# 11:  1.7569e+02  1.7569e+02  4e-01  1e-02  1e-15  8e-05
# 12:  1.7575e+02  1.7575e+02  1e-01  4e-03  1e-15  3e-05
# 13:  1.7576e+02  1.7576e+02  4e-02  1e-03  1e-15  9e-06
AM: Compiling problem (target solver=CVXOPT).
# (CVXPY) Mar 15 12:22:36 AM: Reduction chain: Dcp2Cone -> CvxAttr2Constr -> ConeMatrixStuffing -> CVXOPT
# (CVXPY) Mar 15 12:22:36 AM: Applying reduction Dcp2Cone
# (CVXPY) Mar 15 12:22:36 AM: Applying reduction CvxAttr2Constr
# (CVXPY) Mar 15 12:22:36 AM: Applying reduction ConeMatrixStuffing
# (CVXPY) Mar 15 12:22:37 AM: Applying reduction CVXOPT
# (CVXPY) Mar 15 12:22:37 AM: Finished problem compilation (took 8.097e-01 seconds).
# -------------------------------------------------------------------------------
#                                 Numerical solver
# -------------------------------------------------------------------------------
# (CVXPY) Mar 15 12:22:37 AM: Invoking solver CVXOPT  to obtain a solution.
#      pcost       dcost       gap    pres   dres   k/t
#  0: -9.6010e-14 -1.0956e-14  3e+04  8e+02  5e-16  1e+00
#  1:  3.2309e+01  3.2646e+01  1e+04  3e+02  3e-16  8e-01
#  2:  5.3038e+01  5.3220e+01  2e+03  5e+01  2e-16  2e-01
#  3:  9.7801e+01  9.7878e+01  6e+02  2e+01  4e-16  1e-01
#  4:  1.4141e+02  1.4144e+02  2e+02  6e+00  6e-16  3e-02
#  5:  1.6510e+02  1.6511e+02  7e+01  2e+00  8e-16  1e-02
#  6:  1.7381e+02  1.7382e+02  3e+01  9e-01  9e-16  5e-03
#  7:  1.7714e+02  1.7714e+02  1e+01  4e-01  9e-16  2e-03
#  8:  1.7839e+02  1.7839e+02  5e+00  2e-01  9e-16  1e-03
#  9:  1.7899e+02  1.7899e+02  2e+00  6e-02  9e-16  4e-04
# 10:  1.7924e+02  1.7924e+02  7e-01  2e-02  9e-16  2e-04
# 11:  1.7933e+02  1.7933e+02  3e-01  1e-02  9e-16  7e-05
# 12:  1.7937e+02  1.7937e+02  1e-01  3e-03  9e-16  2e-05
# 13:  1.7938e+02  1.7938e+02  5e-02  1e-03  1e-15  1e-05
# 14:  1.7939e+02  1.7939e+02  1e-02  4e-04  1e-15  3e-06
# 15:  1.7939e+02  1.7939e+02  4e-03  1e-04  1e-15  9e-07
# 16:  1.7939e+02  1.7939e+02  1e-03  4e-05  1e-15  3e-07
# 17:  1.7939e+02  1.7939e+02  3e-04  9e-06  1e-15  6e-08
# 18:  1.7939e+02  1.7939e+02  1e-04  4e-06  9e-16  3e-08
# 19:  1.7939e+02  1.7939e+02  2e-06  7e-08  7e-15  5e-10
# Optimal solution found.
# -------------------------------------------------------------------------------
#                                     Summary
# -------------------------------------------------------------------------------
# (CVXPY) Mar 15 12:23:56 AM: Problem status: optimal
# (CVXPY) Mar 15 12:23:56 AM: Optimal value: 1.794e+02
# (CVXPY) Mar 15 12:23:56 AM: Compilation took 8.097e-01 seconds
# (CVXPY) Mar 15 12:23:56 AM: Solver (including time spent in interface) took 7.852e+01 seconds

# %%
M = round(0.6 * N)
Bs = []

fig, ax = plt.subplots(1, 3, figsize=(30,10))
for i in range(3):
    B = construct_Measurement_Mat(M, N)
    ax[i].imshow(np.reshape(np.sum(B, axis = 0), (Ny, Nx)), cmap='gray')
    ax[i].axis('off')
    Bs.append(B)

# %%
fig, ax = plt.subplots(1, 3, figsize=(30,10))
for i in range(3):
    B = Bs[i]
    y = np.dot(B, vec_F)
    A = np.dot(B, iDCT_mat)
    x = cvx.Variable(N)
    objective = cvx.Minimize(cvx.norm(x, 1))
    constraint = [A @ x == y]
    prob = cvx.Problem(objective, constraint)
    prob.solve(verbose=True, solver='CVXOPT', max_iter=1000, reltol=1e-2, featol=1e-2)
    re_img = np.dot(iDCT_mat, x.value).reshape(Ny, Nx)
    ax[i].imshow(re_img, cmap='gray')
    ax[i].axis('off')
# Out:
# ===============================================================================
#                                      CVXPY
#                                      v1.2.0
# ===============================================================================
# (CVXPY) Mar 15 12:24:25 AM: Your problem has 2173 variables, 1 constraints, and 0 parameters.
# (CVXPY) Mar 15 12:24:25 AM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) Mar 15 12:24:25 AM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) Mar 15 12:24:25 AM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) Mar 15 12:24:25 AM: Compiling problem (target solver=CVXOPT).
# (CVXPY) Mar 15 12:24:25 AM: Reduction chain: Dcp2Cone -> CvxAttr2Constr -> ConeMatrixStuffing -> CVXOPT
# (CVXPY) Mar 15 12:24:25 AM: Applying reduction Dcp2Cone
# (CVXPY) Mar 15 12:24:25 AM: Applying reduction CvxAttr2Constr
# (CVXPY) Mar 15 12:24:25 AM: Applying reduction ConeMatrixStuffing
# (CVXPY) Mar 15 12:24:26 AM: Applying reduction CVXOPT
# (CVXPY) Mar 15 12:24:27 AM: Finished problem compilation (took 1.261e+00 seconds).
# -------------------------------------------------------------------------------
#                                 Numerical solver
# -------------------------------------------------------------------------------
# (CVXPY) Mar 15 12:24:27 AM: Invoking solver CVXOPT  to obtain a solution.
#      pcost       dcost       gap    pres   dres   k/t
#  0:
y = data['y']

# %%
N = 50*50
iDCT_unknown = construct_iDCT_Mat(50, 50)
A = np.dot(B, iDCT_unknown)
x = cvx.Variable(N)
objective = cvx.Minimize(cvx.norm(x, 1))
constraint = [A @ x == y]
prob = cvx.Problem(objective, constraint)
prob.solve(verbose=True, solver='CVXOPT', max_iter=1000, reltol=1e-2, featol=1e-2)
re_unknown = np.dot(iDCT_unknown, x.value).reshape(50, 50)
# Out:
# ===============================================================================
#                                      CVXPY
#                                      v1.2.0
# ===============================================================================
# (CVXPY) Mar 15 12:39:25 AM: Your problem has 2500 variables, 1 constraints, and 0 parameters.
# (CVXPY) Mar 15 12:39:25 AM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) Mar 15 12:39:25 AM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) Mar 15 12:39:25 AM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) Mar 15 12:39:25 AM: Compiling problem (target solver=CVXOPT).
# (CVXPY) Mar 15 12:39:25 AM: Reduction chain: Dcp2Cone -> CvxAttr2Constr -> ConeMatrixStuffing -> CVXOPT
# (CVXPY) Mar 15 12:39:25 AM: Applying reduction Dcp2Cone
# (CVXPY) Mar 15 12:39:25 AM: Applying reduction CvxAttr2Constr
# (CVXPY) Mar 15 12:39:25 AM: Applying reduction ConeMatrixStuffing
# (CVXPY) Mar 15 12:39:27 AM: Applying reduction CVXOPT
# (CVXPY) Mar 15 12:39:28 AM: Finished problem compilation (took 2.275e+00 seconds).
# -------------------------------------------------------------------------------
#                                 Numerical solver
# -------------------------------------------------------------------------------
# (CVXPY) Mar 15 12:39:28 AM: Invoking solver CVXOPT  to obtain a solution.
#      pcost       dcost       gap    pres   dres   k/t
#  0:  7.3544e-15  1.2223e-14  3e+04  1e+03  8e-16  1e+00
#  1:  2.9658e+01  3.0189e+01  1e+04  3e+02  3e-16  8e-01
#  2:  7.2764e+01  7.2857e+01  1e+03  4e+01  4e-16  1e-01
#  3:  2.0177e+02  2.0179e+02  3e+02  8e+00  1e-15  3e-02
#  4:  2.8074e+02  2.8075e+02  1e+02  3e+00  2e-15  1e-02
#  5:  3.0448e+02  3.0449e+02  4e+01  1e+00  2e-15  5e-03
#  6:  3.1328e+02  3.1329e+02  2e+01  6e-01  2e-15  3e-03
#  7:  3.1837e+02  3.1837e+02  8e+00  2e-01  2e-15  1e-03
#  8:  3.2029e+02  3.2029e+02  3e+00  9e-02  3e-15  5e-04
#  9:  3.2099e+02  3.2099e+02  1e+00  4e-02  3e-15  2e-04
# 10:  3.2129e+02  3.2129e+02  5e-01  1e-02  3e-15  9e-05
# 11:  3.2141e+02  3.2141e+02  2e-01  6e-03  3e-15  4e-05
# 12:  3.2146e+02  3.2146e+02  9e-02  2e-03  3e-15  2e-05
# 13:  3.2149e+02  3.2149e+02  2e-02  6e-04  3e-15  4e-06
# 14:  3.2149e+02  3.2149e+02  5e-03  1e-04  3e-15  1e-06
# 15:  3.2149e+02  3.2149e+02  1e-03  4e-05  3e-15  3e-07
# 16:  3.2149e+02  3.2149e+02  3e-04  9e-06  3e-15  6e-08
# 17:  3.2149e+02  3.2149e+02  8e-06  2e-07  3e-15  2e-09
# 18:  3.2149e+02  3.2149e+02  8e-08  2e-09  5e-13  2e-11
# Optimal solution found.
# -------------------------------------------------------------------------------
#                                     Summary
# -------------------------------------------------------------------------------
# (CVXPY) Mar 15 12:42:38 AM: Problem status: optimal
# (CVXPY) Mar 15 12:42:38 AM: Optimal value: 3.215e+02
# (CVXPY) Mar 15 12:42:38 AM: Compilation took 2.275e+00 seconds
# (CVXPY) Mar 15 12:42:38 AM: Solver (including time spent in interface) took 1.909e+02 seconds

# %%
plt.imshow(re_unknown, cmap='gray')
plt.title('Recovered UnknownImage')
plt.axis('off')
plt.show()

# %% [markdown]
# # Nyan Cat!!!
